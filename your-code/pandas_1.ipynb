# %% [markdown]
# # Introduction to Pandas Lab
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# ### 1. Import Numpy and Pandas and alias them to `np` and `pd` respectively.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Create a Pandas Series containing the elements of the list below.

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# creating a Panda Series
panda_sereies = pd.Series(lst)
print(panda_sereies)
# Out:
# 0     5.7
# 1    75.2
# 2    74.4
# 3    84.0
# 4    66.5
# 5    66.3
# 6    55.8
# 7    75.7
# 8    29.1
# 9    43.7
# dtype: float64

# %% [markdown]
# ### 3. Use indexing to return the third value in the Series above.
#
# *Hint: Remember that indexing begins at 0.*

# %%
# index to return the third value in the series
print(panda_sereies[2])
# Out:
# 74.4

# %% [markdown]
# ### 4. Create a Pandas DataFrame from the list of lists below. Each sublist should be represented as a row.

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
# your code here
panda_DataFrame= pd.DataFrame(b)
print(panda_DataFrame)
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# ### 5. Rename the data frame columns based on the names in the list below.
#
# ```py
# list_names = ["Score_1", "Score_2", "Score_3", "Score_4", "Score_5"]
# ```

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
# Renaming the data frame columns
# df = pd.DataFrame(b,columns=["Score_1","Score_2","Score_3","Score_4","Score_5"])

# 10 row names for index, 5 column names for columns
row_names = ["Row_1", "Row_2", "Row_3", "Row_4", "Row_5", "Row_6", "Row_7", "Row_8", "Row_9", "Row_10"]
col_names = ["Score_1", "Score_2", "Score_3", "Score_4", "Score_5"]

# Create DataFrame with both custom index and columns
df = pd.DataFrame(b, index=row_names, columns=col_names)
print(df)
# Out:
#         Score_1  Score_2  Score_3  Score_4  Score_5
# Row_1      53.1     95.0     67.5     35.0     78.4
# Row_2      61.3     40.8     30.8     37.8     87.6
# Row_3      20.6     73.2     44.2     14.6     91.8
# Row_4      57.4      0.1     96.1      4.2     69.5
# Row_5      83.6     20.5     85.4     22.8     35.9
# Row_6      49.0     69.0      0.1     31.8     89.1
# Row_7      23.3     40.7     95.0     83.8     26.9
# Row_8      27.6     26.4     53.8     88.8     68.5
# Row_9      96.6     96.4     53.4     72.4     50.1
# Row_10     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# ### 6. Create a subset of this data frame that contains only the Score 1, 3, and 5 columns.

# %%
# Subset of data frame conatins only Scor1,3,and 5

subset_df = df[["Score_1", "Score_3", "Score_5"]]
display(subset_df)
# Out:
#         Score_1  Score_3  Score_5
# Row_1      53.1     67.5     78.4
# Row_2      61.3     30.8     87.6
# Row_3      20.6     44.2     91.8
# Row_4      57.4     96.1     69.5
# Row_5      83.6     85.4     35.9
# Row_6      49.0      0.1     89.1
# Row_7      23.3     95.0     26.9
# Row_8      27.6     53.8     68.5
# Row_9      96.6     53.4     50.1
# Row_10     73.7     43.2     34.7

# %% [markdown]
# ### 7. From the original data frame, calculate the average Score_3 value.

# %%
# calculate average Score 3
avg_Score3 = df["Score_3"].mean()
print(avg_Score3)
# Out:
# 56.95000000000001

# %% [markdown]
# ### 8. From the original data frame, calculate the maximum Score_4 value.

# %%
# maximum score of score4
max_Score4 = df["Score_4"].max()
print(max_Score4)
# Out:
# 88.8

# %% [markdown]
# ### 9. From the original data frame, calculate the median Score 2 value.

# %%
# median score of score2
median_Score2 = df["Score_2"].median()
print(median_Score2)
# Out:
# 40.75

# %% [markdown]
# ### 10. Create a Pandas DataFrame from the dictionary of product orders below.

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
# creating pandas from dictionary
df =pd.DataFrame(orders)
print(df)
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN          1       1.65     1.65
# 3   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4    PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                      POPCORN HOLDER         7       0.85     5.95
# 6      BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                       PARTY BUNTING         4       4.95    19.80
# 8            JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9       SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# ### 11. Calculate the total quantity ordered and revenue generated from these orders.

# %%
# Total order
total_quantity_order=df['Quantity'].sum()
print("Total Quantity",total_quantity_order)

# Total revenue
total_revenue = df['Revenue'].sum()
print("Total revenue",total_revenue)
# Out:
# Total Quantity 2978
# Total revenue 637.0

# %% [markdown]
# ### 12. Obtain the prices of the most expensive and least expensive items ordered and print the difference.

# %%
# Most expensive
most_expensive=df['UnitPrice'].max()
print("Maximum Value=",most_expensive)

#Least expensive
least_expensive=df['UnitPrice'].min()
print("Minimum Value=",least_expensive)

diffrence= most_expensive -least_expensive
print("Difference = ",diffrence)
# Out:
# Maximum Value= 11.95
# Minimum Value= 0.18
# Difference =  11.77

# %% [markdown]
# ## Let's load another dataset for more exercisesº

# %%
# Run this code:
admissions = pd.read_csv('../Admission_Predict.csv')

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
#print head function
admissions_data =admissions.head()
print(admissions_data)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
# 3           4        314          103                  2  2.0   3.0  8.21
# 4           5        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# ### 1 - Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# check for missing data
has_missing = admissions_data.isnull().values.any()
print(has_missing)
# Out:
# False

# %% [markdown]
# ###  2 -  Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Set the serial number column as the index and keep it as a column

df = admissions_data.set_index('Serial No.', drop=False)#This tells Pandas to copy the values into the index without deleting the original column from the DataFrame.

# View the updated DataFrame
print(df.head().to_string())
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  Chance of Admit
# Serial No.
# 1                    1        337          118                  4  4.5   4.5  9.65         1              0.92
# 2                    2        316          104                  3  3.0   3.5  8.00         1              0.72
# 3                    3        322          110                  3  3.5   2.5  8.67         1              0.80
# 4                    4        314          103                  2  2.0   3.0  8.21         0              0.65
# 5                    5        330          115                  5  4.5   3.0  9.34         1              0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
#view the GRE Score and CGPA
display(df['GRE Score'],df['CGPA'])
# Out:
# Serial No.
# 1    337
# 2    316
# 3    322
# 4    314
# 5    330
# Name: GRE Score, dtype: int64
# Serial No.
# 1    9.65
# 2    8.00
# 3    8.67
# 4    8.21
# 5    9.34
# Name: CGPA, dtype: float64

# %% [markdown]
# ### 3 - In this part of the lab, we would like to test complex conditions on the entire data set at once. Let's start by finding the number of rows where the CGPA is greater than 9 and the student has performed an investigation.

# %%
# Define both conditions inside parentheses
condition = (df['CGPA'] > 9) & (df['Research'] == 1)

# Filter the dataframe and count the number of rows
matching_rows_count = len(df[condition])

print(f"Number of students matching conditions: {matching_rows_count}")
# Out:
# Number of students matching conditions: 2

# %% [markdown]
# ### 4 - Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Define the complex condition
condition = (df['CGPA'] > 9) & (df['SOP'] < 3.5)

# Filter the DataFrame to show all matching rows
matching_rows = df[condition]
print("Matching Rows:")
print(matching_rows)

# Calculate the mean 'Chance of Admit' for these rows
# Note: The original dataset column name often has a trailing space: 'Chance of Admit '
mean_chance = matching_rows['Chance of Admit '].mean()

print(f"\nMean Chance of Admit: {mean_chance}")
# Out:
# Matching Rows:
# Empty DataFrame
# Columns: [Serial No., GRE Score, TOEFL Score, University Rating, SOP, LOR , CGPA, Research, Chance of Admit ]
# Index: []
#
# Mean Chance of Admit: nan
